# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("datascience_salaries.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1171 entries, 0 to 1170
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1171 non-null   int64
#  1   job_title         1171 non-null   object
#  2   job_type          1171 non-null   object
#  3   experience_level  1171 non-null   object
#  4   location          1171 non-null   object
#  5   salary_currency   1171 non-null   object
#  6   salary            1171 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 64.2+ KB

# %%
df.head()
# Out:
#    Unnamed: 0       job_title   job_type experience_level       location  \
# 0           0  Data scientist  Full Time           Senior  New York City
# 1           2  Data scientist  Full Time           Senior         Boston
# 2           3  Data scientist  Full Time           Senior         London
# 3           4  Data scientist  Full Time           Senior         Boston
# 4           5  Data scientist  Full Time           Senior  New York City
#
#   salary_currency  salary
# 0             USD  149000
# 1             USD  120000
# 2             USD   68000
# 3             USD  120000
# 4             USD  149000

# %%
df.drop(columns=['Unnamed: 0','location','salary_currency'], inplace=True)

# %%
df
# Out:
#            job_title    job_type experience_level  salary
# 0     Data scientist   Full Time           Senior  149000
# 1     Data scientist   Full Time           Senior  120000
# 2     Data scientist   Full Time           Senior   68000
# 3     Data scientist   Full Time           Senior  120000
# 4     Data scientist   Full Time           Senior  149000
# ...              ...         ...              ...     ...
# 1166          ML Ops   Full Time           Senior  228000
# 1167          ML Ops   Full Time           Senior  115000
# 1168          ML Ops   Full Time           Senior   76000
# 1169          ML Ops   Full Time           Senior   68000
# 1170          ML Ops  Internship           Senior  135000
#
# [1171 rows x 4 columns]

# %%
df["job_title"].value_counts()
# Out:
# job_title
# Data scientist      394
# Data analyst        368
# Machine learning    289
# Big data            101
# ML Ops               19
# Name: count, dtype: int64

# %%
df["job_type"].value_counts()
# Out:
# job_type
# Full Time     1136
# Internship      35
# Name: count, dtype: int64

# %%
df["experience_level"].value_counts()
# Out:
# experience_level
# Senior       727
# Mid          305
# Entry        126
# Executive     13
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
df['job_title'] = label_encoder.fit_transform(df['job_title'])
df['experience_level'] = label_encoder.fit_transform(df['experience_level'])
df['job_type'] = label_encoder.fit_transform(df['job_type'])

# %%
df
# Out:
#       job_title  job_type  experience_level  salary
# 0             2         0                 3  149000
# 1             2         0                 3  120000
# 2             2         0                 3   68000
# 3             2         0                 3  120000
# 4             2         0                 3  149000
# ...         ...       ...               ...     ...
# 1166          3         0                 3  228000
# 1167          3         0                 3  115000
# 1168          3         0                 3   76000
# 1169          3         0                 3   68000
# 1170          3         1                 3  135000
#
# [1171 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(['salary'], axis=1)
y = df['salary']

# %%
x
# Out:
#       job_title  job_type  experience_level
# 0             2         0                 3
# 1             2         0                 3
# 2             2         0                 3
# 3             2         0                 3
# 4             2         0                 3
# ...         ...       ...               ...
# 1166          3         0                 3
# 1167          3         0                 3
# 1168          3         0                 3
# 1169          3         0                 3
# 1170          3         1                 3
#
# [1171 rows x 3 columns]

# %%
y
# Out:
# 0       149000
# 1       120000
# 2        68000
# 3       120000
# 4       149000
#          ...
# 1166    228000
# 1167    115000
# 1168     76000
# 1169     68000
# 1170    135000
# Name: salary, Length: 1171, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.fit(x_test,y_test)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)
y_pred
# Out:
# array
#        74571.23519059, 64184.93143319, 70913.2317001 , 64184.93143319,
#        36096.31693739, 74571.23519059, 64184.93143319, 78229.23868109,
#        57456.63116628, 77743.14234979, 78229.23868109, 64184.93143319,
#        71500.93841417, 70913.2317001 , 60526.9279427 , 64184.93143319,
#        32438.3134469 , 85545.24566207, 74571.23519059, 74571.23519059,
#        78229.23868109, 78229.23868109, 70913.2317001 , 78229.23868109,
#        85545.24566207, 64184.93143319, 60526.9279427 , 74571.23519059,
#        78229.23868109, 78229.23868109, 43412.32391838])

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
print(lr.score(x_train,y_train))
# Out:
# 0.12993337128708315

# %%
print(lr.score(x_test,y_test))
# Out:
# 0.1751336574456399

# %%
from sklearn.linear_model import Ridge, Lasso

# %%
from sklearn.linear_model import Ridge, Lasso
ridge = Ridge()
ridge.fit(x_train, y_train)
pred_ridge = ridge.predict(x_test)

# %%
pred_ridge
# Out:
# array([56195.12467285, 71844.22430631, 56195.12467285, 75839.54610297,
#        71844.22430631, 75839.54610297, 56195.12467285, 67848.90250966,
#        58192.78557118, 71844.22430631, 75839.54610297, 71844.22430631,
#        75839.54610297, 75839.54610297, 33186.78718198, 73841.88520464,
#        54197.46377452, 58192.78557118, 67848.90250966, 56195.12467285,
#        58192.78557118, 58192.78557118, 69846.56340799, 69846.56340799,
#        56195.12467285, 69846.56340799, 58192.78557118, 69846.56340799,
#        28892.24720258, 62188.10736783, 75839.54610297, 26894.58630425,
#        54197.46377452, 58192.78557118, 67848.90250966, 58192.78557118,
#        30889.9081009 , 31189.12628365, 34885.22989756, 69846.56340799,
#        72143.44248906, 58192.78557118, 54197.46377452, 58192.78557118,
#        75839.54610297, 71844.22430631, 48536.66863269, 58192.78557118,
#        71844.22430631, 28892.24720258, 71844.22430631, 75839.54610297,
#        75839.54610297, 71844.22430631, 71844.22430631, 71844.22430631,
#        28892.24720258, 71844.22430631, 67848.90250966, 34885.22989756,
#        75839.54610297, 69846.56340799, 71844.22430631, 69846.56340799,
#        69846.56340799, 69846.56340799, 56195.12467285, 62188.10736783,
#        71844.22430631, 30889.9081009 , 71844.22430631, 75839.54610297,
#        71844.22430631, 67848.90250966, 56195.12467285, 69846.56340799,
#        71844.22430631, 62188.10736783, 69846.56340799, 71844.22430631,
#        71844.22430631, 71844.22430631, 69846.56340799, 54197.46377452,
#        75839.54610297, 62188.10736783, 69846.56340799, 28892.24720258,
#        75839.54610297, 75839.54610297, 62188.10736783, 71844.22430631,
#        71844.22430631, 56195.12467285, 69846.56340799, 75839.54610297,
#        69846.56340799, 56195.12467285, 71844.22430631, 62188.10736783,
#        58192.78557118, 71844.22430631, 73841.88520464, 71844.22430631,
#        71844.22430631, 28892.24720258, 34885.22989756, 28892.24720258,
#        67848.90250966, 56195.12467285, 71844.22430631, 69846.56340799,
#        69846.56340799, 34885.22989756, 34885.22989756, 71844.22430631,
#        71844.22430631, 71844.22430631, 72143.44248906, 69846.56340799,
#        58192.78557118, 75839.54610297, 28892.24720258, 56195.12467285,
#        75839.54610297, 69846.56340799, 56195.12467285, 75839.54610297,
#        75839.54610297, 71844.22430631, 69846.56340799, 75839.54610297,
#        56195.12467285, 71844.22430631, 58192.78557118, 42543.68593771,
#        56195.12467285, 58192.78557118, 34885.22989756, 71844.22430631,
#        54197.46377452, 71844.22430631, 71844.22430631, 67848.90250966,
#        30889.9081009 , 58192.78557118, 71844.22430631, 28892.24720258,
#        75839.54610297, 56195.12467285, 58192.78557118, 56195.12467285,
#        71844.22430631, 71844.22430631, 34885.22989756, 71844.22430631,
#        71844.22430631, 58192.78557118, 67848.90250966, 56195.12467285,
#        34885.22989756, 40546.02503939, 30889.9081009 , 69846.56340799,
#        30889.9081009 , 30889.9081009 , 58192.78557118, 72143.44248906,
#        28892.24720258, 69846.56340799, 71844.22430631, 69846.56340799,
#        69846.56340799, 62188.10736783, 58192.78557118, 56195.12467285,
#        31189.12628365, 69846.56340799, 71844.22430631, 28892.24720258,
#        56195.12467285, 75839.54610297, 75839.54610297, 67848.90250966,
#        69846.56340799, 75839.54610297, 56195.12467285, 69846.56340799,
#        56195.12467285, 75839.54610297, 75839.54610297, 75839.54610297,
#        69846.56340799, 28892.24720258, 71844.22430631, 71844.22430631,
#        67848.90250966, 60489.66465225, 34885.22989756, 54197.46377452,
#        75839.54610297, 75839.54610297, 69846.56340799, 75839.54610297,
#        69846.56340799, 58192.78557118, 67848.90250966, 58192.78557118,
#        30889.9081009 , 69846.56340799, 58192.78557118, 71844.22430631,
#        48536.66863269, 78136.42518404, 71844.22430631, 58192.78557118,
#        62188.10736783, 67848.90250966, 56195.12467285, 58192.78557118,
#        28892.24720258, 75839.54610297, 69846.56340799, 69846.56340799,
#        71844.22430631, 71844.22430631, 67848.90250966, 71844.22430631,
#        75839.54610297, 58192.78557118, 56195.12467285, 69846.56340799,
#        71844.22430631, 71844.22430631, 34885.22989756])

# %%
print(ridge.score(x_train,y_train))
# Out:
# 0.17326842107162777

# %%
print(ridge.score(x_test,y_test))
# Out:
# 0.14528202101957355

# %%
lasso = Lasso()
lasso.fit(x_train, y_train)
pred_lasso = lasso.predict(x_test)

# %%
print(lasso.score(x_train,y_train))
# Out:
# 0.17326894924299363

# %%
print(lasso.score(x_test,y_test))
# Out:
# 0.14523883846414543

# %%
from sklearn.tree import DecisionTreeRegressor
dtc=DecisionTreeRegressor()
dtc.fit(x_train, y_train)
y_pred_tree = dtc.predict(x_test)

# %%
dtc.score(x_train,y_train)
# Out:
# 0.2368973737072969

# %%
dtc.score(x_test,y_test)
# Out:
# 0.18124396417073008

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train, y_train)
y_pred_rf =rf.predict(x_test)

# %%
rf.score(x_train,y_train)
# Out:
# 0.23555914982793347

# %%
rf.score(x_test,y_test)
# Out:
# 0.18249978258163202

# %%
y_pred = rf.predict(x_test)

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbm = GradientBoostingRegressor()
gbm.fit(x_train, y_train)
y_pred_gbm = gbm.predict(x_test)

# %%
gbm.score(x_train,y_train)
# Out:
# 0.2327787197864737

# %%
gbm.score(x_test,y_test)
# Out:
# 0.1857667422544833

# %%
import joblib,pickle

# %%
joblib.dump(gbm,"gradientboosting.lb")
# Out:
# ['gradientboosting.lb']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.svm import SVC

# %%
base_learners = [
    ('lr', LogisticRegression()),
    ('rf', RandomForestClassifier()),
    ('svc', SVC()),
    ('gb', GradientBoostingClassifier())
]

# %%
voting_model = VotingClassifier(estimators=base_learners)

# %%
voting_model.fit(x_train, y_train)
# Out:
# c:\Users\saniy\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# VotingClassifier(estimators=[('lr', LogisticRegression()),
#                              ('rf', RandomForestClassifier()), ('svc', SVC()),
#                              ('gb', GradientBoostingClassifier())])

# %%
y_pred = voting_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test, y_pred)

# %%
accuracy
# Out:
# 0.574468085106383
